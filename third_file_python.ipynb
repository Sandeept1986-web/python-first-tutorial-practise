# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandeept1986-web/python-first-tutorial-practise/blob/main/third_file_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count=0
while(count<9):
    print(count)
    count=count+1

# %%
for i in range(9):
  print(i)

# %%
j=0
for i in range(5):
  j=j+2;
  if(j==6):
    break
  print(j)

# %%
j=0
for i in range(5):
  j=j+2;
  if(j==6):
    continue
  print(j)

# %%
def print_line():
  print("hello")
print_line()

# %%
def print_line(i):
  print("\n hello"*i)
print_line(7)

# %%
def print_line(x,y):
  print(x+" "+y)
print_line("xxx","yyy")

# %%
def changeme(mylist):
#This change a passed list into this function
  mylist=[1,2,3,4]; # This would assign new reference in my list
  print("Values inside the function", mylist)
  return
mylist = [10,20,30]
changeme(mylist)
print("Values outside the function", mylist)

# %%
def printinfo(name,age):
  print("Name:", name)
  print("Age:", age)
printinfo( age=50, name="miki")

# %%
def print_line(x,y="123"):
  print(x+" "+y)
print_line("xxx","yyy")

# %%
def print_line(lastname,firstname):
  print(lastname+firstname)
print_line(firstname="xxx",lastname="yyy")

# %%
list1=["apple","banana","cherry"]

def printl(food):
  print(food)
printl(list1)

# %%
list1=["apple","banana","cherry"]

def printl(food):
  for x in food:
    print(x)
printl(list1)

# %%
list1=["apple","banana","cherry"]

def printl(x):
    return x*5

li=printl(list1)
print(li)

# %%
total=0
def add(arg1,arg2):
  total=arg1+arg2
  print("Inside the function local total", total)
  return total
add(10,20)
print("Outside the function global total", total)

# %%
total=0
def add(arg1,arg2):
  total=arg1+arg2;
  sum=arg1+arg2
  print(total)
  print(sum)
add(10,20)
print("sum of the number is", total)
