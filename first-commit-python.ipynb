# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandeept1986-web/ansible-test/blob/main/first-commit-python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello world")
# Out:
# Hello world

# %%
print("Have a good day.")
# Out:
# Have a good day.

# %%
print("Learning Python is fun!")
print("This is first class")
# Out:
# Learning Python is fun!
# This is first class
